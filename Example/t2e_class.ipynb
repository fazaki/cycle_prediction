# %%
import os
import sys
import numpy as np
sys.path.insert(0, os.path.abspath('../t2e'))
from t2e import t2e
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings("ignore")
# %load_ext autoreload
# %autoreload 2


path = '../data/'

a = os.path.join(path,'helpdesk.csv')
a = pd.read_csv(a)
b = os.path.join(path,'bpi_12_w.csv')
b = pd.read_csv(b)
c = os.path.join(path,'bpi_12_w_no_repeat.csv')
c = pd.read_csv(c)
d = os.path.join(path,'env_permit.csv')
d = pd.read_csv(d)

df_name = {
    'a':'helpdesk',
    'b':'bpi_12_w',
    'c':'bpi_12_w_no_repeat',
    'd':'env_permit'
}

df_dict = {
    'a': a,
    'b': b,
    'c': c,
    'd': d
}
range_dict = {
    'a': range(2,8,1),
    'b': range(2,22,2),
    'c': range(2,12,2),
    'd': range(2,22,2)
}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from matplotlib import gridspec
fig = plt.figure(figsize=(15, 6)) 
gs = gridspec.GridSpec(2, 2, width_ratios=[1,3])

i = 0
for key, dataset in df_dict.items():

    ax = plt.subplot(gs[i])
    sns.countplot(dataset.groupby(["CaseID"]).agg({"ActivityID":'count'})["ActivityID"], color='gray', ax = ax)
    plt.xlabel("Number of events per trace", fontsize=14)
    plt.ylabel("Count",fontsize=14)
    plt.title("Dataset " + key,fontsize=18)
    i+=1
plt.tight_layout()
plt.plot()
# Out:
# []

# %%
from matplotlib import gridspec
fig = plt.figure(figsize=(15, 6)) 
gs = gridspec.GridSpec(2, 3, width_ratios=[1,1,1])

i = 0
for key, dataset in df_dict.items():

    ax = plt.subplot(gs[i])
    if i == 3:
        ax = plt.subplot(gs[i:])
    sns.countplot(dataset.groupby(["CaseID"]).agg({"ActivityID":'nunique'})["ActivityID"], color='gray', ax = ax)
    plt.xlabel("number of unique activities per trace", fontsize=14)
    plt.ylabel("Count",fontsize=14)
    plt.title("Dataset " + key,fontsize=18)
    i+=1
plt.tight_layout()
plt.plot()
# Out:
# []

# %%
# # save common datasets
# path = '../Tax_paper/data/'

# for dataset in ['d']:
#     t2e_obj = t2e(df_dict[dataset], 
#                   prefix = 2, 
#                   resolution = 's', 
#                   censored = True, 
#                   cen_prc = 0.4)
#     dataset_preprocessed = t2e_obj.preprocess()
#     observed_cases = set(t2e_obj.all_cases) - set(t2e_obj.censored_cases)
#     to_save = df_dict[dataset].loc[df_dict[dataset]['CaseID'].isin(observed_cases)].reset_index(drop=True)
# Out:
# [autoreload of t2e_utils failed: Traceback (most recent call last):
#   File "C:\Users\ebasfad\AppData\Local\Continuum\anaconda3\envs\t2e\lib\site-packages\IPython\extensions\autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\ebasfad\AppData\Local\Continuum\anaconda3\envs\t2e\lib\site-packages\IPython\extensions\autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "C:\Users\ebasfad\AppData\Local\Continuum\anaconda3\envs\t2e\lib\imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "C:\Users\ebasfad\AppData\Local\Continuum\anaconda3\envs\t2e\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "C:\Users\ebasfad\Dropbox\Data Science\01 - Masters\10 - Thesis\time_to_event\t2e_utils.py", line 318
#     print('Case:'case.iloc[0].loc["ActivityID"],'\toriginal_length:',case_length, 'possible_cuts:',x, '\trandom censor:', random_censor)
#                     ^
# SyntaxError: invalid syntax
# ]

# %%
import pickle
import warnings
warnings.filterwarnings("ignore")
import os
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset='a'
res='s'
censored=False
cen_per=0
fit_type:'t2e'
df_results = dict()
prefix = 6
transform = True

print("\ndataset:", dataset, "\tprefix:", prefix)

t2e_obj = t2e(df_dict[dataset], 
              prefix = prefix, 
              resolution = res, 
              censored = censored , 
              cen_prc = cen_per,
              transform = transform
             )
t2e_obj.preprocess()
X_train, X_test, X_val, y_train, y_test, y_val, len_train, len_val, len_test = t2e_obj.smart_split(train_prc = 0.7,
                                                                                                     val_prc = 0.45,
                                                                                                      scaling=True)
# Out:
# dataset: a 	prefix: 6
# all cases 126
# first 10 censored cases []
# 	Total Observed: 126
# 	Training data Observed: 49
# 	Training data Censored: 0
# 	Training data to use: 49
# 	Validation data: 39
# 	Testing data   : 38

# %%
X_train.shape, X_test.shape, X_val.shape, y_train.shape, y_test.shape, y_val.shape
# Out:
# ((49, 6, 10), (38, 6, 10), (39, 6, 10), (49, 2), (38, 2), (39, 2))

# %%
if res == 'd':
    bins = np.arange(0,y_train.max()+1, 1)
elif res == 'h':
    bins = np.arange(0,y_train.max()+24, 24)
elif res == 's':
    bins = np.arange(0,y_train.max()+86400, 86400)
    
plt.figure(figsize=(6,4))
plt.hist(y_train[:,0], bins = bins,label="Train");
# plt.hist(y_val[:,0], bins = bins,label="Val");
plt.hist(y_test[:,0], bins = bins, label="Test", color='lightgreen');
plt.xlabel('Remaining time (T) in seconds')
plt.ylabel('Occurences')
plt.title('Train/Test label distribution')
plt.legend()
plt.show()

# %%
root = 3
root = 1/root
power = 1/root
print(root, power)

plt.figure(figsize=(6,4))
y_conv = (y_train[:,0]**root)

plt.hist(y_conv, bins = 120,label="Train", alpha =1);

y_conv = (y_test[:,0]**root)
# y_conv = (np.log(y_test[:,0]))
plt.hist(y_conv, bins = 120,label="Test", alpha=1, color='lightgreen');

plt.xlabel('Remaining time (T) in seconds')
plt.ylabel('Occurences')
plt.title('Train/Test label distribution')
plt.legend()
plt.show()
# Out:
# 0.3333333333333333 3.0

# %%
print("Layer size:",4, end = " ..... ")
t2e_obj.fit(X_train, y_train, X_val, y_val,size=8, vb = True)
print("Done")
print("Training accomplished in", t2e_obj.fit_time, "seconds")
try:
    test_result_df, mae, accuracy = t2e_obj.evaluate(X_test,y_test)
    print('power:', t2e_obj.power)
    print(len(test_result_df['T_pred'].unique()), 'unique predictions')
    print(np.round(mae,3), 'mae')
except:
    print('evaluation failed')
# Out:
# Layer size: 4 ..... Y_label has been transformed
#
#
# Epoch 1/500
#
# Epoch 00001: val_loss improved from inf to 2.19987, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 149ms/step - loss: 2.5783 - val_loss: 2.1999
# Epoch 2/500
#
# Epoch 00002: val_loss did not improve from 2.19987
# 1/1 [==============================] - 0s 101ms/step - loss: 2.7427 - val_loss: 2.2023
# Epoch 3/500
#
# Epoch 00003: val_loss did not improve from 2.19987
# 1/1 [==============================] - 0s 96ms/step - loss: 2.3641 - val_loss: 2.2057
# Epoch 4/500
#
# Epoch 00004: val_loss did not improve from 2.19987
# 1/1 [==============================] - 0s 131ms/step - loss: 2.4424 - val_loss: 2.2026
# Epoch 5/500
#
# Epoch 00005: val_loss did not improve from 2.19987
# 1/1 [==============================] - 0s 114ms/step - loss: 2.3563 - val_loss: 2.2072
# Epoch 6/500
#
# Epoch 00006: val_loss did not improve from 2.19987
# 1/1 [==============================] - 0s 99ms/step - loss: 2.1901 - val_loss: 2.2082
# Epoch 7/500
#
# Epoch 00007: val_loss did not improve from 2.19987
# 1/1 [==============================] - 0s 98ms/step - loss: 1.9664 - val_loss: 2.2041
# Epoch 8/500
#
# Epoch 00008: val_loss did not improve from 2.19987
# 1/1 [==============================] - 0s 98ms/step - loss: 2.1297 - val_loss: 2.2023
# Epoch 9/500
#
# Epoch 00009: val_loss did not improve from 2.19987
# 1/1 [==============================] - 0s 94ms/step - loss: 1.9629 - val_loss: 2.2028
# Epoch 10/500
#
# Epoch 00010: val_loss did not improve from 2.19987
# 1/1 [==============================] - 0s 112ms/step - loss: 1.8668 - val_loss: 2.2036
# Epoch 11/500
#
# Epoch 00011: val_loss did not improve from 2.19987
# 1/1 [==============================] - 0s 132ms/step - loss: 1.9359 - val_loss: 2.2007
# Epoch 12/500
#
# Epoch 00012: val_loss improved from 2.19987 to 2.19587, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 113ms/step - loss: 1.9851 - val_loss: 2.1959
# Epoch 13/500
#
# Epoch 00013: val_loss improved from 2.19587 to 2.19140, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 118ms/step - loss: 1.9186 - val_loss: 2.1914
# Epoch 14/500
#
# Epoch 00014: val_loss improved from 2.19140 to 2.18061, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 141ms/step - loss: 1.8973 - val_loss: 2.1806
# Epoch 15/500
#
# Epoch 00015: val_loss improved from 2.18061 to 2.17856, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 124ms/step - loss: 1.8061 - val_loss: 2.1786
# Epoch 16/500
#
# Epoch 00016: val_loss improved from 2.17856 to 2.17800, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 126ms/step - loss: 1.7602 - val_loss: 2.1780
# Epoch 17/500
#
# Epoch 00017: val_loss improved from 2.17800 to 2.17489, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 123ms/step - loss: 1.8881 - val_loss: 2.1749
# Epoch 18/500
#
# Epoch 00018: val_loss improved from 2.17489 to 2.17291, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 154ms/step - loss: 1.7884 - val_loss: 2.1729
# Epoch 19/500
#
# Epoch 00019: val_loss did not improve from 2.17291
# 1/1 [==============================] - 0s 123ms/step - loss: 1.7241 - val_loss: 2.1748
# Epoch 20/500
#
# Epoch 00020: val_loss improved from 2.17291 to 2.17161, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 122ms/step - loss: 1.8287 - val_loss: 2.1716
# Epoch 21/500
#
# Epoch 00021: val_loss did not improve from 2.17161
# 1/1 [==============================] - 0s 102ms/step - loss: 1.7118 - val_loss: 2.1724
# Epoch 22/500
#
# Epoch 00022: val_loss improved from 2.17161 to 2.16841, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 144ms/step - loss: 1.7350 - val_loss: 2.1684
# Epoch 23/500
#
# Epoch 00023: val_loss improved from 2.16841 to 2.16671, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 141ms/step - loss: 1.9321 - val_loss: 2.1667
# Epoch 24/500
#
# Epoch 00024: val_loss improved from 2.16671 to 2.16420, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 142ms/step - loss: 1.8207 - val_loss: 2.1642
# Epoch 25/500
#
# Epoch 00025: val_loss improved from 2.16420 to 2.16098, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 143ms/step - loss: 1.8669 - val_loss: 2.1610
# Epoch 26/500
#
# Epoch 00026: val_loss did not improve from 2.16098
# 1/1 [==============================] - 0s 132ms/step - loss: 1.7626 - val_loss: 2.1638
# Epoch 27/500
#
# Epoch 00027: val_loss improved from 2.16098 to 2.15974, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 123ms/step - loss: 1.7442 - val_loss: 2.1597
# Epoch 28/500
#
# Epoch 00028: val_loss improved from 2.15974 to 2.15872, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 132ms/step - loss: 1.8421 - val_loss: 2.1587
# Epoch 29/500
#
# Epoch 00029: val_loss improved from 2.15872 to 2.15777, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 155ms/step - loss: 1.7803 - val_loss: 2.1578
# Epoch 30/500
#
# Epoch 00030: val_loss improved from 2.15777 to 2.15330, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 143ms/step - loss: 1.8351 - val_loss: 2.1533
# Epoch 31/500
#
# Epoch 00031: val_loss improved from 2.15330 to 2.15127, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 138ms/step - loss: 1.7482 - val_loss: 2.1513
# Epoch 32/500
#
# Epoch 00032: val_loss improved from 2.15127 to 2.14932, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 126ms/step - loss: 1.7112 - val_loss: 2.1493
# Epoch 33/500
#
# Epoch 00033: val_loss improved from 2.14932 to 2.14633, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 158ms/step - loss: 1.7735 - val_loss: 2.1463
# Epoch 34/500
#
# Epoch 00034: val_loss improved from 2.14633 to 2.14247, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 140ms/step - loss: 1.7597 - val_loss: 2.1425
# Epoch 35/500
#
# Epoch 00035: val_loss improved from 2.14247 to 2.14234, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 122ms/step - loss: 1.6801 - val_loss: 2.1423
# Epoch 36/500
#
# Epoch 00036: val_loss improved from 2.14234 to 2.14175, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 144ms/step - loss: 1.7775 - val_loss: 2.1418
# Epoch 37/500
#
# Epoch 00037: val_loss improved from 2.14175 to 2.13999, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 123ms/step - loss: 1.7108 - val_loss: 2.1400
# Epoch 38/500
#
# Epoch 00038: val_loss improved from 2.13999 to 2.13817, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 144ms/step - loss: 1.7452 - val_loss: 2.1382
# Epoch 39/500
#
# Epoch 00039: val_loss improved from 2.13817 to 2.13565, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 124ms/step - loss: 1.6960 - val_loss: 2.1357
# Epoch 40/500
#
# Epoch 00040: val_loss did not improve from 2.13565
# 1/1 [==============================] - 0s 123ms/step - loss: 1.7060 - val_loss: 2.1357
# Epoch 41/500
#
# Epoch 00041: val_loss improved from 2.13565 to 2.13544, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 144ms/step - loss: 1.6490 - val_loss: 2.1354
# Epoch 42/500
#
# Epoch 00042: val_loss improved from 2.13544 to 2.13524, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 132ms/step - loss: 1.6505 - val_loss: 2.1352
# Epoch 43/500
#
# Epoch 00043: val_loss improved from 2.13524 to 2.13350, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 145ms/step - loss: 1.6406 - val_loss: 2.1335
# Epoch 44/500
#
# Epoch 00044: val_loss improved from 2.13350 to 2.13289, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 138ms/step - loss: 1.6594 - val_loss: 2.1329
# Epoch 45/500
#
# Epoch 00045: val_loss improved from 2.13289 to 2.13220, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 135ms/step - loss: 1.6755 - val_loss: 2.1322
# Epoch 46/500
#
# Epoch 00046: val_loss improved from 2.13220 to 2.12980, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 125ms/step - loss: 1.6385 - val_loss: 2.1298
# Epoch 47/500
#
# Epoch 00047: val_loss improved from 2.12980 to 2.12792, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 139ms/step - loss: 1.6558 - val_loss: 2.1279
# Epoch 48/500
#
# Epoch 00048: val_loss did not improve from 2.12792
# 1/1 [==============================] - 0s 134ms/step - loss: 1.6571 - val_loss: 2.1292
# Epoch 49/500
#
# Epoch 00049: val_loss did not improve from 2.12792
# 1/1 [==============================] - 0s 109ms/step - loss: 1.6489 - val_loss: 2.1281
# Epoch 50/500
#
# Epoch 00050: val_loss improved from 2.12792 to 2.12686, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 119ms/step - loss: 1.6421 - val_loss: 2.1269
# Epoch 51/500
#
# Epoch 00051: val_loss did not improve from 2.12686
# 1/1 [==============================] - 0s 116ms/step - loss: 1.6950 - val_loss: 2.1283
# Epoch 52/500
#
# Epoch 00052: val_loss did not improve from 2.12686
# 1/1 [==============================] - 0s 103ms/step - loss: 1.6177 - val_loss: 2.1292
# Epoch 53/500
#
# Epoch 00053: val_loss did not improve from 2.12686
# 1/1 [==============================] - 0s 97ms/step - loss: 1.6244 - val_loss: 2.1306
# Epoch 54/500
#
# Epoch 00054: val_loss did not improve from 2.12686
# 1/1 [==============================] - 0s 96ms/step - loss: 1.5697 - val_loss: 2.1297
# Epoch 55/500
#
# Epoch 00055: val_loss did not improve from 2.12686
# 1/1 [==============================] - 0s 97ms/step - loss: 1.5249 - val_loss: 2.1326
# Epoch 56/500
#
# Epoch 00056: val_loss did not improve from 2.12686
# 1/1 [==============================] - 0s 106ms/step - loss: 1.5937 - val_loss: 2.1313
# Epoch 57/500
#
# Epoch 00057: val_loss did not improve from 2.12686
# 1/1 [==============================] - 0s 129ms/step - loss: 1.6176 - val_loss: 2.1318
# Epoch 58/500
#
# Epoch 00058: val_loss did not improve from 2.12686
# 1/1 [==============================] - 0s 114ms/step - loss: 1.5979 - val_loss: 2.1275
# Epoch 59/500
#
# Epoch 00059: val_loss improved from 2.12686 to 2.12475, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 119ms/step - loss: 1.5749 - val_loss: 2.1247
# Epoch 60/500
#
# Epoch 00060: val_loss improved from 2.12475 to 2.12421, saving model to ../output_files/best_model.h5
# 1/1 [==============================] - 0s 134ms/step - loss: 1.6173 - val_loss: 2.1242
# Epoch 61/500
#
# Epoch 00061: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 103ms/step - loss: 1.5848 - val_loss: 2.1247
# Epoch 62/500
#
# Epoch 00062: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 98ms/step - loss: 1.6020 - val_loss: 2.1259
# Epoch 63/500
#
# Epoch 00063: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 95ms/step - loss: 1.5476 - val_loss: 2.1291
# Epoch 64/500
#
# Epoch 00064: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 95ms/step - loss: 1.5289 - val_loss: 2.1305
# Epoch 65/500
#
# Epoch 00065: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 119ms/step - loss: 1.5283 - val_loss: 2.1351
# Epoch 66/500
#
# Epoch 00066: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 125ms/step - loss: 1.5169 - val_loss: 2.1376
# Epoch 67/500
#
# Epoch 00067: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 101ms/step - loss: 1.4925 - val_loss: 2.1371
# Epoch 68/500
#
# Epoch 00068: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 97ms/step - loss: 1.5556 - val_loss: 2.1372
# Epoch 69/500
#
# Epoch 00069: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 103ms/step - loss: 1.5272 - val_loss: 2.1461
# Epoch 70/500
#
# Epoch 00070: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 109ms/step - loss: 1.5276 - val_loss: 2.1499
# Epoch 71/500
#
# Epoch 00071: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 95ms/step - loss: 1.5089 - val_loss: 2.1485
# Epoch 72/500
#
# Epoch 00072: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 95ms/step - loss: 1.5159 - val_loss: 2.1468
# Epoch 73/500
#
# Epoch 00073: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 97ms/step - loss: 1.5547 - val_loss: 2.1482
# Epoch 74/500
#
# Epoch 00074: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 98ms/step - loss: 1.5090 - val_loss: 2.1510
# Epoch 75/500
#
# Epoch 00075: val_loss did not improve from 2.12421
# 1/1 [==============================] - 0s 133ms/step - loss: 1.4606 - val_loss: 2.1452
# Epoch 00075: early stopping
# model loaded successfully
# Done
# Training accomplished in 9.0 seconds
# Y_label is restored
# evaluation failed

# %%
y_pred = t2e_obj.predict(X_train)
plt.scatter(
    x = y_train[:,0], 
    y = y_pred
)

# %%
y_pred = t2e_obj.predict(X_train)
plt.scatter(
    x = y_train[:,0]**t2e_obj.power, 
    y = y_pred**t2e_obj.power
)

# %%
test_results_df, mae = t2e_obj.evaluate(X_test,y_test)
# Out:
# Y_label is restored

# %%
mae
# Out:
# 4.784490016123222

# %%
test_results_df
# Out:
#             T    U      alpha      beta      T_pred  error (days)        MAE  \
# 0        12.0  1.0  42.311066  1.001129    0.000111      0.000139   0.000139
# 1       718.0  1.0  45.835339  1.095003  118.823113      0.006935   0.006935
# 2         7.0  1.0  39.970264  0.928563    0.000000      0.000081   0.000081
# 3    258568.0  1.0  49.024685  1.044315   13.461747      2.992529   2.992529
# 4   1723975.0  1.0  40.081902  0.960338    0.000000     19.953414  19.953414
# 5     86515.0  1.0  35.214458  0.949213    0.000000      1.001331   1.001331
# 6        11.0  1.0  31.560442  0.972861    0.000000      0.000127   0.000127
# 7   1787930.0  1.0  42.073074  0.977916    0.000000     20.693634  20.693634
# 8         5.0  1.0  39.926029  0.941026    0.000000      0.000058   0.000058
# 9        44.0  1.0  41.296661  0.967681    0.000000      0.000509   0.000509
# 10  1204864.0  1.0  45.642166  0.979811    0.000000     13.945185  13.945185
# 11    18400.0  1.0  36.757042  0.910270    0.000000      0.212963   0.212963
# 12      898.0  1.0  41.351681  0.992042    0.000000      0.010394   0.010394
# 13  1233342.0  1.0  45.609272  1.013017    0.238074     14.274789  14.274789
# 14  1201600.0  1.0  42.822464  0.973144    0.000000     13.907407  13.907407
# 15       47.0  1.0  44.697964  0.996250    0.000000      0.000544   0.000544
# 16  1293179.0  1.0  45.110493  0.998884    0.000000     14.967350  14.967350
# 17   239425.0  1.0  40.434452  0.954103    0.000000      2.771123   2.771123
# 18    90095.0  1.0  43.682949  0.970903    0.000000      1.042766   1.042766
# 19       11.0  1.0  41.828743  1.022297    0.975316      0.000116   0.000116
# 20        8.0  1.0  45.432026  1.011422    0.157223      0.000091   0.000091
# 21  1458108.0  1.0  45.918804  1.088083   94.580831     16.875155  16.875155
# 22        1.0  1.0  42.939392  0.999382    0.000000      0.000012   0.000012
# 23       56.0  1.0  46.891788  0.983050    0.000000      0.000648   0.000648
# 24   524533.0  1.0  42.016254  0.919327    0.000000      6.070984   6.070984
# 25        1.0  1.0  36.002388  0.983831    0.000000      0.000012   0.000012
# 26        7.0  1.0  37.186733  0.960600    0.000000      0.000081   0.000081
# 27        2.0  1.0  42.287617  0.970757    0.000000      0.000023   0.000023
# 28        7.0  1.0  38.370819  0.915906    0.000000      0.000081   0.000081
# 29       13.0  1.0  40.510803  0.986487    0.000000      0.000150   0.000150
# 30       42.0  1.0  38.443035  0.944597    0.000000      0.000486   0.000486
# 31        9.0  1.0  30.786463  0.983208    0.000000      0.000104   0.000104
# 32  1298331.0  1.0  39.329395  1.012734    0.142649     15.026978  15.026978
# 33  1286955.0  1.0  33.059307  0.950198    0.000000     14.895312  14.895312
# 34  1735609.0  1.0  46.856716  0.983852    0.000000     20.088067  20.088067
# 35   265319.0  1.0  43.234142  0.979047    0.000000      3.070822   3.070822
# 36        5.0  1.0  40.639729  0.961980    0.000000      0.000058   0.000058
# 37       14.0  1.0  38.625095  0.934310    0.000000      0.000162   0.000162
#
#     Accurate
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
# 5       True
# 6       True
# 7      False
# 8       True
# 9       True
# 10     False
# 11      True
# 12      True
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18      True
# 19      True
# 20      True
# 21     False
# 22      True
# 23      True
# 24     False
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# 30      True
# 31      True
# 32     False
# 33     False
# 34     False
# 35     False
# 36      True
# 37      True

# %%
plot_predictions_insights(test_result_df)
# Out:
# No handles with labels found to put in legend.

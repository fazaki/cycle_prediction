# %%
import cycle_prediction
cycle_prediction.__version__
# Out:
# '1.1.0'

# %%
import numpy as np
import pandas as pd
from numpy.random import seed
seed(1)

from cycle_prediction.t2e import t2e
from cycle_prediction.weibull_utils import plot_top_predictions, plot_predictions_insights

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec
import pickle
import warnings
warnings.filterwarnings("ignore")
import os
# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
path = '../data/'

a = os.path.join(path,'helpdesk.csv')
a = pd.read_csv(a)
b = os.path.join(path,'bpi_12_w.csv')
b = pd.read_csv(b)
c = os.path.join(path,'bpi_12_w_no_repeat.csv')
c = pd.read_csv(c)
d = os.path.join(path,'env_permit.csv')
d = pd.read_csv(d)

df_name = {
    'a':'helpdesk',
    'b':'bpi_12_w',
    'c':'bpi_12_w_no_repeat',
    'd':'env_permit'
}

df_dict = {
    'a': a,
    'b': b,
    'c': c,
    'd': d
}
range_dict = {
    'a': range(2,8,1),
    'b': range(2,22,2),
    'c': range(2,12,2),
    'd': range(2,22,2)
}

# %%
dataset='b'
res='d'
censored=True
cen_per=0.5
fit_type:'t2e'
transform = False
prefix=8
##########################################################
print("\ndataset:", dataset, "\tprefix:", prefix)

t2e_obj = t2e(df_dict[dataset],
              prefix = prefix,
              resolution = res,
              censored = censored,
              cen_prc = cen_per,
              fit_type = 't2e',
              transform = transform
             )
t2e_obj.preprocess_dev()
X_train, X_test, X_val, y_train, y_test, y_val, len_train, len_val, len_test = t2e_obj.smart_split(train_prc = 0.7,
                                                                                                     val_prc = 0.45,
                                                                                                      scaling=True)
print(X_train.shape, X_test.shape, X_val.shape, y_train.shape, y_test.shape, y_val.shape)
# Out:
# dataset: b 	prefix: 8
# all cases 3353
# first 10 censored cases [178269 188164 182296 193177 206147 212280 176515 175192 188554 210008]
# 	Total Observed: 1677
# 	Training data Observed: 646
# 	Training data Censored: 1676
# 	Training data to use: 2322
# 	Validation data: 527
# 	Testing data   : 504
# (2322, 8, 8) (504, 8, 8) (527, 8, 8) (2322, 2) (504, 2) (527, 2)

# %%
# if res == 'd':
#     bins = np.arange(0,y_train.max()+1, 1)
# elif res == 'h':
#     bins = np.arange(0,y_train.max()+24, 24)
# elif res == 's':
#     bins = np.arange(0,y_train.max()+86400, 86400)
    
# plt.figure(figsize=(6,4))
# plt.hist(y_train[:,0], bins = bins,label="Train");
# # plt.hist(y_val[:,0], bins = bins,label="Val");
# plt.hist(y_test[:,0], bins = bins, label="Test", color='lightgreen');
# plt.xlabel('Remaining time (T) in seconds')
# plt.ylabel('Occurences')
# plt.title('Train/Test label distribution')
# plt.legend()
# plt.show()

# %%
# root = 3
# root = 1/root
# power = 1/root
# print(root, power)

# plt.figure(figsize=(6,4))
# y_conv = (y_train[:,0]**root)

# plt.hist(y_conv, bins = 120,label="Train", alpha =1);

# y_conv = (y_test[:,0]**root)
# # y_conv = (np.log(y_test[:,0]))
# plt.hist(y_conv, bins = 120,label="Test", alpha=1, color='lightgreen');

# plt.xlabel('Remaining time (T) in seconds')
# plt.ylabel('Occurences')
# plt.title('Train/Test label distribution')
# plt.legend()
# plt.show()

# %%
print("Layer size:",8, end = " ..... ")
t2e_obj.fit(X_train, y_train, X_val, y_val,size=8, vb = True)
print("Done")
print("Training accomplished in", t2e_obj.fit_time, "seconds")
try:
    test_result_df, mae, accuracy = t2e_obj.evaluate(X_test,y_test)
    print('power:', t2e_obj.power)
    print(len(test_result_df['T_pred'].unique()), 'unique predictions')
    print(np.round(mae,3), 'mae')
except:
    print('evaluation failed')
# Out:
# Layer size: 8 .....
#
# Epoch 1/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.5314
# Epoch 00001: val_loss improved from inf to 5.19942, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 138ms/step - loss: 1.6672 - val_loss: 5.1994
# Epoch 2/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.3078
# Epoch 00002: val_loss improved from 5.19942 to 5.19424, saving model to output/best_model.h5
# 19/19 [==============================] - 2s 120ms/step - loss: 1.4194 - val_loss: 5.1942
# Epoch 3/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.1853
# Epoch 00003: val_loss improved from 5.19424 to 5.13516, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 133ms/step - loss: 1.3159 - val_loss: 5.1352
# Epoch 4/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.1347
# Epoch 00004: val_loss improved from 5.13516 to 4.94714, saving model to output/best_model.h5
# 19/19 [==============================] - 2s 127ms/step - loss: 1.2467 - val_loss: 4.9471
# Epoch 5/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0963
# Epoch 00005: val_loss improved from 4.94714 to 4.74147, saving model to output/best_model.h5
# 19/19 [==============================] - 2s 122ms/step - loss: 1.2040 - val_loss: 4.7415
# Epoch 6/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0977
# Epoch 00006: val_loss improved from 4.74147 to 4.44607, saving model to output/best_model.h5
# 19/19 [==============================] - 2s 130ms/step - loss: 1.2014 - val_loss: 4.4461
# Epoch 7/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0873
# Epoch 00007: val_loss improved from 4.44607 to 4.28734, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 133ms/step - loss: 1.1736 - val_loss: 4.2873
# Epoch 8/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0837
# Epoch 00008: val_loss improved from 4.28734 to 4.16776, saving model to output/best_model.h5
# 19/19 [==============================] - 2s 131ms/step - loss: 1.1697 - val_loss: 4.1678
# Epoch 9/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0692
# Epoch 00009: val_loss improved from 4.16776 to 4.11812, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 134ms/step - loss: 1.1521 - val_loss: 4.1181
# Epoch 10/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0610
# Epoch 00010: val_loss improved from 4.11812 to 4.10941, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 135ms/step - loss: 1.1395 - val_loss: 4.1094
# Epoch 11/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0591
# Epoch 00011: val_loss improved from 4.10941 to 4.07623, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 166ms/step - loss: 1.1406 - val_loss: 4.0762
# Epoch 12/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0565
# Epoch 00012: val_loss improved from 4.07623 to 4.02894, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 184ms/step - loss: 1.1419 - val_loss: 4.0289
# Epoch 13/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0476
# Epoch 00013: val_loss improved from 4.02894 to 4.00308, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 169ms/step - loss: 1.1254 - val_loss: 4.0031
# Epoch 14/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0579
# Epoch 00014: val_loss improved from 4.00308 to 3.98893, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 173ms/step - loss: 1.1357 - val_loss: 3.9889
# Epoch 15/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0470
# Epoch 00015: val_loss improved from 3.98893 to 3.98150, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 155ms/step - loss: 1.1239 - val_loss: 3.9815
# Epoch 16/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0546
# Epoch 00016: val_loss improved from 3.98150 to 3.93872, saving model to output/best_model.h5
# 19/19 [==============================] - 2s 131ms/step - loss: 1.1343 - val_loss: 3.9387
# Epoch 17/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0594
# Epoch 00017: val_loss improved from 3.93872 to 3.93145, saving model to output/best_model.h5
# 19/19 [==============================] - 3s 151ms/step - loss: 1.1371 - val_loss: 3.9315
# Epoch 18/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0498
# Epoch 00018: val_loss improved from 3.93145 to 3.90091, saving model to output/best_model.h5
# 19/19 [==============================] - 2s 125ms/step - loss: 1.1278 - val_loss: 3.9009
# Epoch 19/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0533
# Epoch 00019: val_loss did not improve from 3.90091
# 19/19 [==============================] - 3s 135ms/step - loss: 1.1339 - val_loss: 3.9056
# Epoch 20/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0422
# Epoch 00020: val_loss improved from 3.90091 to 3.90049, saving model to output/best_model.h5
# 19/19 [==============================] - 2s 126ms/step - loss: 1.1188 - val_loss: 3.9005
# Epoch 21/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0488
# Epoch 00021: val_loss improved from 3.90049 to 3.85151, saving model to output/best_model.h5
# 19/19 [==============================] - 5s 247ms/step - loss: 1.1318 - val_loss: 3.8515
# Epoch 22/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0426
# Epoch 00022: val_loss improved from 3.85151 to 3.82813, saving model to output/best_model.h5
# 19/19 [==============================] - 2s 130ms/step - loss: 1.1180 - val_loss: 3.8281
# Epoch 23/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0482
# Epoch 00023: val_loss improved from 3.82813 to 3.80488, saving model to output/best_model.h5
# 19/19 [==============================] - 2s 127ms/step - loss: 1.1191 - val_loss: 3.8049
# Epoch 24/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0486
# Epoch 00024: val_loss did not improve from 3.80488
# 19/19 [==============================] - 2s 131ms/step - loss: 1.1172 - val_loss: 3.8193
# Epoch 25/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0457
# Epoch 00025: val_loss did not improve from 3.80488
# 19/19 [==============================] - 3s 173ms/step - loss: 1.1117 - val_loss: 3.8120
# Epoch 26/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0402
# Epoch 00026: val_loss did not improve from 3.80488
# 19/19 [==============================] - 2s 113ms/step - loss: 1.1069 - val_loss: 3.8197
# Epoch 27/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0452
# Epoch 00027: val_loss improved from 3.80488 to 3.80065, saving model to output/best_model.h5
# 19/19 [==============================] - 4s 208ms/step - loss: 1.1183 - val_loss: 3.8006
# Epoch 28/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0490
# Epoch 00028: val_loss did not improve from 3.80065
# 19/19 [==============================] - 4s 212ms/step - loss: 1.1196 - val_loss: 3.8137
# Epoch 29/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0500
# Epoch 00029: val_loss did not improve from 3.80065
# 19/19 [==============================] - 3s 169ms/step - loss: 1.1156 - val_loss: 3.8528
# Epoch 30/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0272
# Epoch 00030: val_loss did not improve from 3.80065
# 19/19 [==============================] - 2s 129ms/step - loss: 1.0910 - val_loss: 3.8375
# Epoch 31/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0417
# Epoch 00031: val_loss did not improve from 3.80065
# 19/19 [==============================] - 3s 134ms/step - loss: 1.1056 - val_loss: 3.8581
# Epoch 32/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0301
# Epoch 00032: val_loss did not improve from 3.80065
# 19/19 [==============================] - 3s 138ms/step - loss: 1.1038 - val_loss: 3.8613
# Epoch 33/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0328
# Epoch 00033: val_loss did not improve from 3.80065
# 19/19 [==============================] - 3s 142ms/step - loss: 1.1010 - val_loss: 3.8869
# Epoch 34/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0377
# Epoch 00034: val_loss did not improve from 3.80065
# 19/19 [==============================] - 3s 143ms/step - loss: 1.1034 - val_loss: 3.8628
# Epoch 35/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0368
# Epoch 00035: val_loss did not improve from 3.80065
# 19/19 [==============================] - 2s 129ms/step - loss: 1.0981 - val_loss: 3.8536
# Epoch 36/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0298
# Epoch 00036: val_loss did not improve from 3.80065
# 19/19 [==============================] - 2s 100ms/step - loss: 1.0934 - val_loss: 3.8483
# Epoch 37/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0263
# Epoch 00037: val_loss did not improve from 3.80065
# 19/19 [==============================] - 2s 98ms/step - loss: 1.0918 - val_loss: 3.8431
# Epoch 38/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0192
# Epoch 00038: val_loss did not improve from 3.80065
# 19/19 [==============================] - 2s 98ms/step - loss: 1.0876 - val_loss: 3.8652
# Epoch 39/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0294
# Epoch 00039: val_loss did not improve from 3.80065
# 19/19 [==============================] - 2s 102ms/step - loss: 1.0910 - val_loss: 3.8065
# Epoch 40/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0391
# Epoch 00040: val_loss did not improve from 3.80065
# 19/19 [==============================] - 2s 100ms/step - loss: 1.1014 - val_loss: 3.8024
# Epoch 41/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0198
# Epoch 00041: val_loss did not improve from 3.80065
# 19/19 [==============================] - 2s 124ms/step - loss: 1.0865 - val_loss: 3.9161
# Epoch 42/500
# 18/19 [===========================>..] - ETA: 0s - loss: 1.0307
# Epoch 00042: val_loss did not improve from 3.80065
# 19/19 [==============================] - 2s 104ms/step - loss: 1.0973 - val_loss: 3.8987
# Epoch 00042: early stopping
# model loaded successfully
# Done
# Training accomplished in 112.0 seconds
# evaluation failed

# %%
y_pred = t2e_obj.predict(X_test)
test_results_df, mae = t2e_obj.evaluate(X_test,y_test)
plot_predictions_insights(test_results_df)
# Out:
# No handles with labels found to put in legend.

# %%
plot_top_predictions(test_results_df,lim=5)

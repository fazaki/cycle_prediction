# %%
import numpy as np
import pandas as pd
from numpy.random import seed
seed(1)

import matplotlib.pyplot as plt
import seaborn as sns
from cycle_prediction.t2e import t2e
from cycle_prediction.weibull_utils import plot_top_predictions,weibull_pdf, weibull_mode

import pandas as pd
from matplotlib import gridspec
import seaborn as sns
import pickle
import pickle
import warnings
warnings.filterwarnings("ignore")
import os
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = '../data/'

a = os.path.join(path,'helpdesk.csv')
a = pd.read_csv(a)
b = os.path.join(path,'bpi_12_w.csv')
b = pd.read_csv(b)
c = os.path.join(path,'bpi_12_w_no_repeat.csv')
c = pd.read_csv(c)
d = os.path.join(path,'env_permit.csv')
d = pd.read_csv(d)

df_name = {
    'a':'helpdesk',
    'b':'bpi_12_w',
    'c':'bpi_12_w_no_repeat',
    'd':'env_permit'
}

df_dict = {
    'a': a,
    'b': b,
    'c': c,
    'd': d
}
range_dict = {
    'a': range(2,8,1),
    'b': range(2,22,2),
    'c': range(2,12,2),
    'd': range(2,22,2)
}

# %%
# import sys
# sys.path.append('../cycle_prediction/')
# from weibull_utils import plot_predictions_insights
# from weibull_utils import plot_top_predictions,weibull_pdf, weibull_mode
# from t2e import t2e

# %%
dataset='b'
res='d'
censored=True
cen_per=0.4
fit_type:'t2e'
transform = False
prefix=8
##########################################################
print("\ndataset:", dataset, "\tprefix:", prefix)

t2e_obj = t2e(df_dict[dataset],
              prefix = prefix,
              resolution = res,
              censored = censored,
              cen_prc = cen_per,
              fit_type = 't2e',
              transform = transform
             )
t2e_obj.preprocess_dev()
X_train, X_test, X_val, y_train, y_test, y_val, len_train, len_val, len_test = t2e_obj.smart_split(train_prc = 0.7,
                                                                                                     val_prc = 0.45,
                                                                                                      scaling=True)
print(X_train.shape, X_test.shape, X_val.shape, y_train.shape, y_test.shape, y_val.shape)
# Out:
# dataset: b 	prefix: 8
# all cases 3353
# first 10 censored cases [178269 188164 182296 193177 206147 212280 176515 175192 188554 210008]
# 	Total Observed: 2012
# 	Training data Observed: 775
# 	Training data Censored: 1341
# 	Training data to use: 2116
# 	Validation data: 633
# 	Testing data   : 604
# (2116, 8, 8) (604, 8, 8) (633, 8, 8) (2116, 2) (604, 2) (633, 2)

# %%
if res == 'd':
    bins = np.arange(0,y_train.max()+1, 1)
elif res == 'h':
    bins = np.arange(0,y_train.max()+24, 24)
elif res == 's':
    bins = np.arange(0,y_train.max()+86400, 86400)
    
plt.figure(figsize=(6,4))
plt.hist(y_train[:,0], bins = bins,label="Train");
# plt.hist(y_val[:,0], bins = bins,label="Val");
plt.hist(y_test[:,0], bins = bins, label="Test", color='lightgreen');
plt.xlabel('Remaining time (T) in seconds')
plt.ylabel('Occurences')
plt.title('Train/Test label distribution')
plt.legend()
plt.show()

# %%
root = 3
root = 1/root
power = 1/root
print(root, power)

plt.figure(figsize=(6,4))
y_conv = (y_train[:,0]**root)

plt.hist(y_conv, bins = 120,label="Train", alpha =1);

y_conv = (y_test[:,0]**root)
# y_conv = (np.log(y_test[:,0]))
plt.hist(y_conv, bins = 120,label="Test", alpha=1, color='lightgreen');

plt.xlabel('Remaining time (T) in seconds')
plt.ylabel('Occurences')
plt.title('Train/Test label distribution')
plt.legend()
plt.show()
# Out:
# 0.3333333333333333 3.0

# %%
print("Layer size:",8, end = " ..... ")
t2e_obj.fit(X_train, y_train, X_val, y_val,size=8, vb = True)
print("Done")
print("Training accomplished in", t2e_obj.fit_time, "seconds")
try:
    test_result_df, mae, accuracy = t2e_obj.evaluate(X_test,y_test)
    print('power:', t2e_obj.power)
    print(len(test_result_df['T_pred'].unique()), 'unique predictions')
    print(np.round(mae,3), 'mae')
except:
    print('evaluation failed')
# Out:
# Layer size: 8 .....
#
# Epoch 1/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.8479
# Epoch 00001: val_loss improved from inf to 4.33512, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 216ms/step - loss: 1.9469 - val_loss: 4.3351
# Epoch 2/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.6116
# Epoch 00002: val_loss improved from 4.33512 to 4.32825, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 215ms/step - loss: 1.7037 - val_loss: 4.3282
# Epoch 3/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.4393
# Epoch 00003: val_loss improved from 4.32825 to 4.22409, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 213ms/step - loss: 1.5322 - val_loss: 4.2241
# Epoch 4/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.3603
# Epoch 00004: val_loss improved from 4.22409 to 3.97885, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 237ms/step - loss: 1.4574 - val_loss: 3.9788
# Epoch 5/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.3341
# Epoch 00005: val_loss improved from 3.97885 to 3.78157, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 255ms/step - loss: 1.4264 - val_loss: 3.7816
# Epoch 6/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.3019
# Epoch 00006: val_loss improved from 3.78157 to 3.63880, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 212ms/step - loss: 1.3876 - val_loss: 3.6388
# Epoch 7/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2758
# Epoch 00007: val_loss improved from 3.63880 to 3.56029, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 228ms/step - loss: 1.3617 - val_loss: 3.5603
# Epoch 8/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2623
# Epoch 00008: val_loss improved from 3.56029 to 3.45779, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 212ms/step - loss: 1.3453 - val_loss: 3.4578
# Epoch 9/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2578
# Epoch 00009: val_loss improved from 3.45779 to 3.39555, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 213ms/step - loss: 1.3428 - val_loss: 3.3956
# Epoch 10/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2453
# Epoch 00010: val_loss improved from 3.39555 to 3.32813, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 226ms/step - loss: 1.3276 - val_loss: 3.3281
# Epoch 11/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2524
# Epoch 00011: val_loss improved from 3.32813 to 3.27201, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 225ms/step - loss: 1.3330 - val_loss: 3.2720
# Epoch 12/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2493
# Epoch 00012: val_loss improved from 3.27201 to 3.21505, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 219ms/step - loss: 1.3330 - val_loss: 3.2150
# Epoch 13/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2466
# Epoch 00013: val_loss improved from 3.21505 to 3.17869, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 215ms/step - loss: 1.3286 - val_loss: 3.1787
# Epoch 14/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2470
# Epoch 00014: val_loss improved from 3.17869 to 3.14959, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 213ms/step - loss: 1.3333 - val_loss: 3.1496
# Epoch 15/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2351
# Epoch 00015: val_loss improved from 3.14959 to 3.12116, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 215ms/step - loss: 1.3195 - val_loss: 3.1212
# Epoch 16/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2419
# Epoch 00016: val_loss improved from 3.12116 to 3.09560, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 216ms/step - loss: 1.3254 - val_loss: 3.0956
# Epoch 17/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2362
# Epoch 00017: val_loss improved from 3.09560 to 3.07383, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 226ms/step - loss: 1.3190 - val_loss: 3.0738
# Epoch 18/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2403
# Epoch 00018: val_loss improved from 3.07383 to 3.07257, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 212ms/step - loss: 1.3211 - val_loss: 3.0726
# Epoch 19/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2429
# Epoch 00019: val_loss improved from 3.07257 to 3.05106, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 212ms/step - loss: 1.3267 - val_loss: 3.0511
# Epoch 20/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2320
# Epoch 00020: val_loss improved from 3.05106 to 3.03942, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 223ms/step - loss: 1.3130 - val_loss: 3.0394
# Epoch 21/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2297
# Epoch 00021: val_loss improved from 3.03942 to 3.03178, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 229ms/step - loss: 1.3129 - val_loss: 3.0318
# Epoch 22/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2316
# Epoch 00022: val_loss improved from 3.03178 to 3.01763, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 232ms/step - loss: 1.3159 - val_loss: 3.0176
# Epoch 23/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2317
# Epoch 00023: val_loss improved from 3.01763 to 3.01113, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 228ms/step - loss: 1.3157 - val_loss: 3.0111
# Epoch 24/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2295
# Epoch 00024: val_loss improved from 3.01113 to 3.00413, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 226ms/step - loss: 1.3127 - val_loss: 3.0041
# Epoch 25/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2250
# Epoch 00025: val_loss improved from 3.00413 to 3.00176, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 219ms/step - loss: 1.3083 - val_loss: 3.0018
# Epoch 26/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2246
# Epoch 00026: val_loss did not improve from 3.00176
# 17/17 [==============================] - 4s 209ms/step - loss: 1.3075 - val_loss: 3.0156
# Epoch 27/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2249
# Epoch 00027: val_loss did not improve from 3.00176
# 17/17 [==============================] - 4s 220ms/step - loss: 1.3100 - val_loss: 3.0089
# Epoch 28/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2198
# Epoch 00028: val_loss did not improve from 3.00176
# 17/17 [==============================] - 4s 215ms/step - loss: 1.3017 - val_loss: 3.0094
# Epoch 29/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2253
# Epoch 00029: val_loss did not improve from 3.00176
# 17/17 [==============================] - 4s 216ms/step - loss: 1.3090 - val_loss: 3.0130
# Epoch 30/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2203
# Epoch 00030: val_loss did not improve from 3.00176
# 17/17 [==============================] - 4s 213ms/step - loss: 1.3023 - val_loss: 3.0051
# Epoch 31/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2194
# Epoch 00031: val_loss improved from 3.00176 to 3.00095, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 218ms/step - loss: 1.3018 - val_loss: 3.0010
# Epoch 32/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2328
# Epoch 00032: val_loss improved from 3.00095 to 2.99887, saving model to output/best_model.h5
# 17/17 [==============================] - 4s 216ms/step - loss: 1.3151 - val_loss: 2.9989
# Epoch 33/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2170
# Epoch 00033: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 216ms/step - loss: 1.2998 - val_loss: 3.0275
# Epoch 34/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2173
# Epoch 00034: val_loss did not improve from 2.99887
# 17/17 [==============================] - 3s 202ms/step - loss: 1.3029 - val_loss: 3.0250
# Epoch 35/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2198
# Epoch 00035: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 215ms/step - loss: 1.3028 - val_loss: 3.0172
# Epoch 36/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2183
# Epoch 00036: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 227ms/step - loss: 1.3017 - val_loss: 3.0073
# Epoch 37/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2186
# Epoch 00037: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 218ms/step - loss: 1.3023 - val_loss: 3.0101
# Epoch 38/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2245
# Epoch 00038: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 220ms/step - loss: 1.3073 - val_loss: 3.0208
# Epoch 39/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2194
# Epoch 00039: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 224ms/step - loss: 1.3033 - val_loss: 3.0205
# Epoch 40/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2167
# Epoch 00040: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 213ms/step - loss: 1.2984 - val_loss: 3.0058
# Epoch 41/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2200
# Epoch 00041: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 211ms/step - loss: 1.3044 - val_loss: 3.0035
# Epoch 42/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2191
# Epoch 00042: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 217ms/step - loss: 1.3006 - val_loss: 3.0175
# Epoch 43/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2135
# Epoch 00043: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 224ms/step - loss: 1.2947 - val_loss: 3.0192
# Epoch 44/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2095
# Epoch 00044: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 215ms/step - loss: 1.2923 - val_loss: 3.0121
# Epoch 45/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2064
# Epoch 00045: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 215ms/step - loss: 1.2897 - val_loss: 3.0148
# Epoch 46/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2108
# Epoch 00046: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 213ms/step - loss: 1.2931 - val_loss: 3.0217
# Epoch 47/500
# 16/17 [===========================>..] - ETA: 0s - loss: 1.2060
# Epoch 00047: val_loss did not improve from 2.99887
# 17/17 [==============================] - 4s 217ms/step - loss: 1.2872 - val_loss: 3.0225
# Epoch 00047: early stopping
# model loaded successfully
# Done
# Training accomplished in 175.0 seconds
# evaluation failed

# %%
y_pred = t2e_obj.predict(X_test)

# %%
test_results_df, mae = t2e_obj.evaluate(X_test,y_test)

# %%
plot_predictions_insights(test_results_df)
# Out:
# No handles with labels found to put in legend.

# %%
plot_top_predictions(test_results_df,lim=5)
